# %% [markdown]
# <a href="https://colab.research.google.com/github/gynmidia/Imersao_dados_4/blob/main/Imersao_dados_4_aula01_Pesquisa_Imoveis_Sao_Paulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Documentação do pandas: https://pandas.pydata.org/docs/

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %% [markdown]
# dados.head()

# %%
dados.sample(10)
# Out:
#                                    Rua             Bairro     Cidade  \
# 4040                         Rua Mário        Vila Romana  São Paulo
# 4182                               NaN            Boaçava  São Paulo
# 2201                    Rua Petrópolis             Sumaré  São Paulo
# 1510                 Rua Santo Eufredo     Jardim Guedala  São Paulo
# 3952  Rua Doutor Manoel Maria Tourinho           Pacaembu  São Paulo
# 1918                Rua Bento de Abreu        Vila Romana  São Paulo
# 2001           Rua General Eloy Alfaro       Vila Mariana  São Paulo
# 3151                Rua Capote Valente          Pinheiros  São Paulo
# 9807                               NaN       Vila Mariana  São Paulo
# 1102                 Rua Sônia Ribeiro  Brooklin Paulista  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 4040       157        3          4      3  R$ 1.250.000
# 4182       521        4          5      4  R$ 4.400.000
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
type(tem_imoveis_vila)
# Out:
# pandas.core.series.Series

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
type(imoveis_vila_mariana)
# Out:
# pandas.core.frame.DataFrame

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
type(imoveis_vila_mariana)
# Out:
# pandas.core.frame.DataFrame

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %%
n_imoveis_bairro.plot.area()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %% [markdown]
# Resposta Desafio 1

# %%
df_teste1 = pd.DataFrame({'A': [1, 1, 2, 1, 2],
                        'B': [2, 2, 3, 4, 5],
                          'C': [1, 2, 1, 1, 2]}, columns=['A', 'B', 'C'])
df_teste1
# Out:
#    A  B  C
# 0  1  2  1
# 1  1  2  2
# 2  2  3  1
# 3  1  4  1
# 4  2  5  2

# %%
df_teste1.groupby('A').mean()
# Out:
#           B         C
# A
# 1  2.666667  1.333333
# 2  4.000000  1.500000

# %%
dados.groupby('Bairro').mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas
# Bairro
# Aclimação          253.056818  3.318182   3.079545  2.909091
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       294.337209  3.151163   3.790698  3.906977
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        191.000000  3.153846   3.076923  2.461538
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 4 columns]

# %%
dados.groupby('Bairro')['Metragem'].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# Resposta Desafio 2

# %%
dados[dados.Bairro == "Aricanduva"]
# Out:
#       Rua      Bairro     Cidade  Metragem  Quartos  Banheiros  Vagas  \
# 8696  NaN  Aricanduva  São Paulo       278        3          3      2
#
#            Valor
# 8696  R$ 480.000

# %%
dados[dados["Bairro"] == "Barra Funda"]
# Out:
#                                      Rua       Bairro     Cidade  Metragem  \
# 142                   Rua Tagipuru, 168   Barra Funda  São Paulo       170
# 463                         Rua Cruzeiro  Barra Funda  São Paulo        70
# 545             Rua dos Americanos, 687   Barra Funda  São Paulo       150
# 552        Rua Conselheiro Brotero, 121   Barra Funda  São Paulo       170
# 1465           Rua Leonardo Jones Júnior  Barra Funda  São Paulo       120
# 1524           Rua Leonardo Jones Júnior  Barra Funda  São Paulo       125
# 2065       Rua Doutor Roberto Mercatelli  Barra Funda  São Paulo        87
# 2164       Rua Doutor Roberto Mercatelli  Barra Funda  São Paulo        92
# 3245                                 NaN  Barra Funda  São Paulo        44
# 3281                                 NaN  Barra Funda  São Paulo        49
# 5171                        Rua Cruzeiro  Barra Funda  São Paulo       150
# ...

# %% [markdown]
# Resposta Desafio 3

# %%
media_metragem_bairro = dados.groupby('Bairro')['Metragem'].mean()
media_metragem_bairro.head(5).plot.bar(x='Bairro', rot=10)

# %% [markdown]
# Gráfico em barras para mostrar a média da metragem dos 5 primeiros
#
# ---
#
# bairros.

# %%
conta_colunas_bairro = dados.groupby('Bairro').count()
conta_colunas_bairro['Banheiros'].head(5).plot.pie()

# %% [markdown]
# Gráfico em pizza para mostrar em qual bairro estão a maioria dos banheiros.

# %% [markdown]
# Resposta Desafio 4

# %% [markdown]
# Médias por bairro.

# %%
dados.groupby('Bairro').mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas
# Bairro
# Aclimação          253.056818  3.318182   3.079545  2.909091
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       294.337209  3.151163   3.790698  3.906977
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  433.444988  3.938875   4.838631  5.004890
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        191.000000  3.153846   3.076923  2.461538
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          340.250000  3.500000   3.250000  5.250000
#
# [701 rows x 4 columns]

# %% [markdown]
# Medianas por bairro.

# %%
dados.groupby('Bairro').median()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas
# Bairro
# Aclimação             227.5      3.0        3.0    3.0
# Alto da Boa Vista     378.0      4.0        5.5    4.0
# Alto da Lapa          255.0      3.0        4.0    4.0
# Alto da Mooca         182.5      3.0        2.0    4.0
# Alto de Pinheiros     412.0      4.0        5.0    4.0
# ...                     ...      ...        ...    ...
# Vila Água Funda       143.0      2.0        2.0    2.0
# Água Branca           174.0      3.0        3.0    2.0
# Água Fria             174.5      3.0        4.0    2.0
# Água Funda            139.0      3.0        2.5    2.0
# Água Rasa             180.0      3.0        2.0    4.0
#
# [701 rows x 4 columns]

# %% [markdown]
# Mínimos por bairro.

# %%
dados.groupby('Bairro').min()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                       Cidade  Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação          São Paulo       104        2          1      1
# Alto da Boa Vista  São Paulo       315        4          3      3
# Alto da Lapa       São Paulo        46        1          1      1
# Alto da Mooca      São Paulo        84        2          1      1
# Alto de Pinheiros  São Paulo       100        2          1      1
# ...                      ...       ...      ...        ...    ...
# Vila Água Funda    São Paulo        90        2          2      2
# Água Branca        São Paulo        91        2          1      1
# ...

# %% [markdown]
# Máximos por bairro.

# %%
dados.groupby('Bairro').max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#                       Cidade  Metragem  Quartos  Banheiros  Vagas  \
# Bairro
# Aclimação          São Paulo      1500        6          7      8
# Alto da Boa Vista  São Paulo       595        5          7      7
# Alto da Lapa       São Paulo      1133        5          8     12
# Alto da Mooca      São Paulo       805        6          7      6
# Alto de Pinheiros  São Paulo      1530        7         11     15
# ...                      ...       ...      ...        ...    ...
# Vila Água Funda    São Paulo       200        5          3      4
# Água Branca        São Paulo       400        4          5      7
# ...

# %% [markdown]
# Resposta Desafio 5

# %%
nao_tem_rua = (dados["Rua"].isna())
imoveis_sem_rua = dados[nao_tem_rua]
imoveis_sem_rua
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...
